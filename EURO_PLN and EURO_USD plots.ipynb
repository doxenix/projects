# %% [markdown]
# # Storytelling Data Visualization on Exchange Rates
#
# In this project we will take a look at data set with Daily Exchange Rates per Euro 1999-2021. We can find here comparison to most of world values.
#
# We will create 2 plots using matplotlib library, one with currency fluctuations during financial crisis and COVID-19 in EURO/USD and second one in EURO/PLN.
#
# Data set was made by Daria Chemkaeva and is available [here](https://www.kaggle.com/lsind18/euro-exchange-daily-rates-19992020)
#
# Let's start wiith opening our data set.

# %%
#opening file
import pandas as pd

exchange_rates = pd.read_csv('euro-daily-hist_1999_2020.csv')
#display 5 first rows
exchange_rates.head()
# Out:
#   Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 0   2021-01-08               1.5758           1.9558            6.5748
# 1   2021-01-07               1.5836           1.9558            6.5172
# 2   2021-01-06               1.5824           1.9558            6.5119
# 3   2021-01-05               1.5927           1.9558            6.5517
# 4   2021-01-04               1.5928           1.9558            6.3241
#
#   [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ] [Cypriot pound ]  \
# 0             1.5543         1.0827                   7.9184              NaN
# 1             1.5601         1.0833                   7.9392              NaN
# 2             1.5640         1.0821                   7.9653              NaN
# 3             1.5651         1.0803                   7.9315              NaN
# 4             1.5621         1.0811                   7.9484              NaN
#
# ...

# %% [markdown]
# Our data set contains 41 columns, 40 diffrent currencies included.

# %%
#display 5 last rows
exchange_rates.tail()
# Out:
#      Period\Unit: [Australian dollar ] [Bulgarian lev ] [Brazilian real ]  \
# 5694   1999-01-08               1.8406              NaN               NaN
# 5695   1999-01-07               1.8474              NaN               NaN
# 5696   1999-01-06               1.8820              NaN               NaN
# 5697   1999-01-05               1.8944              NaN               NaN
# 5698   1999-01-04               1.9100              NaN               NaN
#
#      [Canadian dollar ] [Swiss franc ] [Chinese yuan renminbi ]  \
# 5694             1.7643         1.6138                      NaN
# 5695             1.7602         1.6165                      NaN
# 5696             1.7711         1.6116                      NaN
# 5697             1.7965         1.6123                      NaN
# 5698             1.8004         1.6168                      NaN
#
#      [Cypriot pound ] [Czech koruna ] [Danish krone ]          ...            \
# ...

# %%
#show info about dataframe columns
exchange_rates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5699 entries, 0 to 5698
# Data columns (total 41 columns):
# Period\Unit:                5699 non-null object
# [Australian dollar ]        5699 non-null object
# [Bulgarian lev ]            5297 non-null object
# [Brazilian real ]           5431 non-null object
# [Canadian dollar ]          5699 non-null object
# [Swiss franc ]              5699 non-null object
# [Chinese yuan renminbi ]    5431 non-null object
# [Cypriot pound ]            2346 non-null object
# [Czech koruna ]             5699 non-null object
# [Danish krone ]             5699 non-null object
# [Estonian kroon ]           3130 non-null object
# [UK pound sterling ]        5699 non-null object
# [Greek drachma ]            520 non-null object
# [Hong Kong dollar ]         5699 non-null object
# [Croatian kuna ]            5431 non-null object
# [Hungarian forint ]         5699 non-null object
# [Indonesian rupiah ]        5699 non-null object
# ...

# %% [markdown]
# Our dataset contains 41 columns with diffrent currencies. Some of them have null values. We also see that most data type of each column are objects, only few are numeric.

# %%
#rename colums 
exchange_rates.rename(columns={'[US dollar ]': 'US_dollar',
                               'Period\\Unit:': 'Time',
                                '[Polish zloty ]' : 'PLN'
                              },
                      inplace=True)

#convert Time column to datatime type
exchange_rates['Time'] = pd.to_datetime(exchange_rates['Time'])
#sorting by time
exchange_rates.sort_values('Time',inplace=True)

# %%
#isolate Time and USD
euro_to_dollar = exchange_rates[['Time', 'US_dollar']]
#display 5 first rows
euro_to_dollar.head()
# Out:
#            Time US_dollar
# 5698 1999-01-04    1.1789
# 5697 1999-01-05    1.1790
# 5696 1999-01-06    1.1743
# 5695 1999-01-07    1.1632
# 5694 1999-01-08    1.1659

# %%
#isolate Time and PLN
euro_to_pln = exchange_rates[['Time', 'PLN']]
#display 5 first rows
euro_to_pln.head()
# Out:
#            Time     PLN
# 5698 1999-01-04  4.0712
# 5697 1999-01-05  4.0245
# 5696 1999-01-06  4.0065
# 5695 1999-01-07  4.0165
# 5694 1999-01-08  4.0363

# %%
euro_to_pln['PLN'].value_counts().sort_values()
# Out:
# 3.9538     1
# 4.2836     1
# 4.7002     1
# 4.4827     1
# 3.3449     1
# 4.2983     1
# 3.9806     1
# 3.2700     1
# 4.1239     1
# 4.7081     1
# 4.0086     1
# 4.4942     1
# 3.7785     1
# 3.9322     1
# 4.6673     1
# 4.4413     1
# 4.3221     1
# 4.5193     1
# 4.4152     1
# 4.2434     1
# 4.0736     1
# 3.9801     1
# 4.0800     1
# 3.9663     1
# 4.1140     1
# 4.1605     1
# 4.1385     1
# 4.3242     1
# 3.9455     1
# 4.1277     1
#           ..
# 4.2298     4
# 4.3500     4
# 4.1801     4
# 4.1803     4
# 4.1665     4
# 4.2848     4
# 4.0893     4
# 4.0920     4
# 4.2045     5
# 4.2950     5
# 4.2563     5
# 4.1893     5
# 4.0875     5
# 4.1828     5
# 4.2837     5
# 4.2540     5
# 4.1808     5
# 4.1040     5
# 4.2974     5
# 4.3740     5
# 4.2968     5
# 4.2033     5
# 3.9383     5
# 4.1697     5
# 4.1645     5
# 4.2953     6
# 4.1770     6
# 4.2925     6
# 4.1765     6
# -         62
# Name: PLN, Length: 4094, dtype: int64

# %%
euro_to_dollar['US_dollar'].value_counts().sort_values()
# Out:
# 0.9524     1
# 1.2070     1
# 0.9009     1
# 1.3585     1
# 0.9639     1
# 1.0871     1
# 0.8563     1
# 1.4132     1
# 1.2459     1
# 1.3063     1
# 1.3382     1
# 0.8692     1
# 1.0345     1
# 0.9214     1
# 0.8525     1
# 1.1302     1
# 1.5167     1
# 1.2928     1
# 1.4018     1
# 1.3524     1
# 0.8815     1
# 1.1383     1
# 1.4721     1
# 1.0725     1
# 1.3990     1
# 0.8545     1
# 1.2535     1
# 0.9824     1
# 1.0675     1
# 1.4276     1
#           ..
# 1.3260     5
# 1.1813     5
# 1.2309     5
# 1.2850     5
# 1.1221     5
# 1.0737     5
# 1.1154     5
# 1.3588     5
# 1.1389     5
# 1.3200     5
# 1.0592     5
# 1.3596     5
# 1.1236     5
# 1.1115     5
# 1.1284     5
# 1.3532     6
# 1.1797     6
# 1.2713     6
# 1.1193     6
# 1.0888     6
# 1.1268     6
# 1.1218     6
# 1.3373     6
# 1.3086     6
# 1.1346     6
# 1.0867     6
# 1.1305     7
# 1.1215     8
# 1.2276     9
# -         62
# Name: US_dollar, Length: 3528, dtype: int64

# %% [markdown]
# 62 values in US_dollar and PLN column are '-' character. We will remove them

# %%
#removing rows with '-' in US_dollar column
euro_to_dollar = euro_to_dollar[euro_to_dollar['US_dollar'] != '-']
#convert to float
euro_to_dollar['US_dollar'] = euro_to_dollar['US_dollar'].astype(float)

#removing rows with '-' in PLN column
euro_to_pln = euro_to_pln[euro_to_pln['PLN'] != '-']
#convert to float
euro_to_pln['PLN'] = euro_to_pln['PLN'].astype(float)

# %%
#import matplotlib
import matplotlib.pyplot as plt
#add this row to enables Jupyter to generate the graphs
# %matplotlib inline
plt.plot(euro_to_dollar['Time'],
         euro_to_dollar['US_dollar'])
plt.show()

# %%
plt.plot(euro_to_pln['Time'],
         euro_to_pln['PLN'])
plt.show()

# %%
#creat new column with moving average 30 days USD
euro_to_dollar['rolling_mean'] = euro_to_dollar['US_dollar'].rolling(30).mean()
#display 5 last rows
euro_to_dollar.tail()
# Out:
#         Time  US_dollar  rolling_mean
# 4 2021-01-04     1.2296      1.211170
# 3 2021-01-05     1.2271      1.212530
# 2 2021-01-06     1.2338      1.213987
# 1 2021-01-07     1.2276      1.215357
# 0 2021-01-08     1.2250      1.216557

# %%
#creat new column with moving average 30 days PLN
euro_to_pln['rolling_mean'] = euro_to_pln['PLN'].rolling(30).mean()
#display 5 last rows
euro_to_pln.tail()
# Out:
#         Time     PLN  rolling_mean
# 4 2021-01-04  4.5475      4.479480
# 3 2021-01-05  4.5473      4.482260
# 2 2021-01-06  4.5160      4.483677
# 1 2021-01-07  4.4998      4.484783
# 0 2021-01-08  4.5113      4.486230

# %%
#isolate rows with year 2006-2021 only USD
euro_to_dollar_06_21 = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2006)]
#display 5 last rows
euro_to_dollar_06_21.tail()
# Out:
#         Time  US_dollar  rolling_mean
# 4 2021-01-04     1.2296      1.211170
# 3 2021-01-05     1.2271      1.212530
# 2 2021-01-06     1.2338      1.213987
# 1 2021-01-07     1.2276      1.215357
# 0 2021-01-08     1.2250      1.216557

# %%
euro_to_dollar_18_21 = euro_to_dollar.copy()[euro_to_dollar['Time'].dt.year >= 2018]

# %%
#isolate rows with year 2007-2009 only USD
euro_to_dollar_07_09 = euro_to_dollar.copy()[(euro_to_dollar['Time'].dt.year >= 2007) & (euro_to_dollar['Time'].dt.year <= 2009)]
euro_to_dollar_07_09.head()
# Out:
#            Time  US_dollar  rolling_mean
# 3612 2007-01-02     1.3270      1.314257
# 3611 2007-01-03     1.3231      1.315780
# 3610 2007-01-04     1.3106      1.316663
# 3609 2007-01-05     1.3084      1.317563
# 3608 2007-01-08     1.3006      1.317963

# %%
#isolate rows with year 2006-2021 only PLN
euro_to_pln_06_21 = euro_to_pln.copy()[(euro_to_pln['Time'].dt.year >= 2006)]
#display 5 last rows
euro_to_pln_06_21.tail()
# Out:
#         Time     PLN  rolling_mean
# 4 2021-01-04  4.5475      4.479480
# 3 2021-01-05  4.5473      4.482260
# 2 2021-01-06  4.5160      4.483677
# 1 2021-01-07  4.4998      4.484783
# 0 2021-01-08  4.5113      4.486230

# %%
#isolate rows with year 2007-2009 only PLN
euro_to_pln_18_21 = euro_to_pln.copy()[euro_to_pln['Time'].dt.year >= 2018]

#isolate rows with year 2007-2009 only PLN
euro_to_pln_07_09 = euro_to_pln.copy()[(euro_to_pln['Time'].dt.year >= 2007) & (euro_to_pln['Time'].dt.year <= 2009)]
euro_to_pln_07_09.head()
# Out:
#            Time     PLN  rolling_mean
# 3612 2007-01-02  3.8287      3.813907
# 3611 2007-01-03  3.8270      3.814843
# 3610 2007-01-04  3.8521      3.816270
# 3609 2007-01-05  3.8731      3.818797
# 3608 2007-01-08  3.8663      3.820987

# %% [markdown]
# ## Creating EURO-USD plot

# %%
#import matplotlib style and dates, import datetime
import matplotlib.style as style
from datetime import datetime
from matplotlib.dates import date2num


### Adding the FiveThirtyEight style
style.use('fivethirtyeight')

### Adding the plot
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(euro_to_dollar_06_21['Time'], euro_to_dollar_06_21['rolling_mean'], 
       linewidth=1, color='#A6D785')

### Highlighting the 2007-2008 period
ax.plot(euro_to_dollar_07_09 ['Time'],
        euro_to_dollar_07_09 ['rolling_mean'],
        linewidth=3, color='#e23d28')

### Highlighting the 2018-2021 period
ax.plot(euro_to_dollar_18_21 ['Time'],
        euro_to_dollar_18_21 ['rolling_mean'],
        linewidth=3, color='#e23d28')

### Highlihting the peak of the crisis
ax.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2009 Recession",color="gray", alpha=0.3)
ax.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2021,1,8)),
           label="2009 Recession",color="gray", alpha=0.3)

# Set x-labels            
ax.set_xticks([date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), date2num(datetime(2011,1,1)), 
               date2num(datetime(2013,1,1)), date2num(datetime(2015,1,1)), date2num(datetime(2017,1,1)), 
              date2num(datetime(2019,1,1)), date2num(datetime(2021,1,1))])
# Set y-labels
ax.set_yticks([1.0, 1.1, 1.2, 1.3, 1.4, 1.5, 1.6])
ax.set_yticklabels(['', '1.1', '', '1.3', '', '1.5', ''])

# Adding text under 

### Adding title Highlihting peak
ax.text(date2num(datetime(2006,12,15)), 1.60, "Financial crisis", color = 'gray',
       size=11, weight='bold')
ax.text(date2num(datetime(2019,11,1)), 1.60, "COVID-19", color = 'gray',
       size=11, weight='bold')

ax.text(date2num(datetime(2006,1,1)), 1.7, "EURO-USD fluctations during financial crisis and COVID-19",
       weight='bold', size=15)
ax.text(date2num(datetime(2006,1,1)), 1.66, "Euro-USD exchange rates 2006 - 2010 and 2016 - 2021",
        size=12)

### Add some transparency to the grid
ax.grid(alpha=0.5)

ax.text(date2num(datetime(2006,1,1)), 0.9, '©DominikZalewski' + ' '*127 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

plt.show()

# %% [markdown]
# ## Creating EURO - PLN plot

# %%
### Adding the plot
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(euro_to_pln_06_21['Time'], euro_to_pln_06_21['rolling_mean'], 
       linewidth=1, color='#A6D785')

### Highlighting the 2007-2008 period
ax.plot(euro_to_pln_07_09 ['Time'],
        euro_to_pln_07_09 ['rolling_mean'],
        linewidth=3, color='#e23d28')

### Highlighting the 2018-2021 period
ax.plot(euro_to_pln_18_21 ['Time'],
        euro_to_pln_18_21 ['rolling_mean'],
        linewidth=3, color='#e23d28')

### Highlihting the peak of the crisis
ax.axvspan(date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), 
           label="2009 Recession",color="gray", alpha=0.3)
ax.axvspan(date2num(datetime(2020,1,1)), date2num(datetime(2021,1,8)),
           label="2009 Recession",color="gray", alpha=0.3)

# Set x-labels            
ax.set_xticks([date2num(datetime(2007,1,1)), date2num(datetime(2009,1,1)), date2num(datetime(2011,1,1)), 
               date2num(datetime(2013,1,1)), date2num(datetime(2015,1,1)), date2num(datetime(2017,1,1)), 
              date2num(datetime(2019,1,1)), date2num(datetime(2021,1,1))])
# Set y-labels
ax.set_yticks([3.5, 4.0, 4.5])
#ax.set_yticklabels(['', '1.1', '', '1.3', '', '1.5', ''])

# Adding text under 

### Adding title Highlihting peak
ax.text(date2num(datetime(2006,12,15)), 4.8, "Financial crisis", color = 'gray',
       size=11, weight='bold')
ax.text(date2num(datetime(2019,11,1)), 4.8, "COVID-19", color = 'gray',
       size=11, weight='bold')

ax.text(date2num(datetime(2006,1,1)), 5.1, "EURO-PLN fluctations during financial crisis and COVID-19",
       weight='bold', size=15)
ax.text(date2num(datetime(2006,1,1)), 5, "Euro-PLN exchange rates 2006 - 2010 and 2016 - 2021",
        size=12)

### Add some transparency to the grid
ax.grid(alpha=0.5)

ax.text(date2num(datetime(2006,1,1)), 2.9, '©DominikZalewski' + ' '*127 + 'Source: European Central Bank',
        color = '#f0f0f0', backgroundcolor = '#4d4d4d',
        size=10)

plt.show()
